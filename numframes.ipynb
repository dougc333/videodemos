# %%
import cv
import cv2

#find num frames in video2.avi
#somethign wrong with avi writes, macbook convert to .mov first
#vc = cv2.VideoCapture('/Users/dc/TestCode/TestMatlab/videodemos/video2.mov')
vc = cv2.VideoCapture('/Users/dc/videodemos/test.m4v')
(ret,frame) = vc.read()
numFrames = 0

while frame!=None:
    (ret,frame) = vc.read()
    print "numFrames: " , numFrames
    numFrames +=1
    
print 'done'
#total = 528+1 since we read one before starting while loop. We lost 1 frame in creating file
#bc we read one frame before starting read in videofile.avi
#974 + 1 frames for test.m4v
# Out:
# /Users/dc/venv/lib/python2.7/site-packages/ipykernel/__main__.py:11: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
# numFrames:  0
# numFrames:  1
# numFrames:  2
# numFrames:  3
# numFrames:  4
# numFrames:  5
# numFrames:  6
# numFrames:  7
# numFrames:  8
# numFrames:  9
# numFrames:  10
# numFrames:  11
# numFrames:  12
# numFrames:  13
# numFrames:  14
# numFrames:  15
# numFrames:  16
# numFrames:  17
# numFrames:  18
# numFrames:  19
# numFrames:  20
# numFrames:  21
# numFrames:  22
# numFrames:  23
# numFrames:  24
# numFrames:  25
# numFrames:  26
# numFrames:  27
# numFrames:  28
# numFrames:  29
# numFrames:  30
# numFrames:  31
# numFrames:  32
# numFrames:  33
# numFrames:  34
# numFrames:  35
# numFrames:  36
# numFrames:  37
# numFrames:  38
# numFrames:  39
# numFrames:  40
# numFrames:  41
# numFrames:  42
# numFrames:  43
# numFrames:  44
# numFrames:  45
# numFrames:  46
# numFrames:  47
# numFrames:  48
# ...
